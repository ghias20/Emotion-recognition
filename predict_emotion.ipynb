# %%
import numpy as np
from sklearn.svm import SVC
def predict_emotion(audio_path):
    audio, sr = librosa.load(audio_path, duration=3, offset=0.5)
    mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=40)
    features = np.mean(mfcc.T, axis=0).reshape(1, -1)

    pred = svm_model.predict(features)[0]

    for emo, num in emotion_to_num.items():
        if num == pred:
            return emo

# %%
predict_emotion('harvard1.wav')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 predict_emotion('harvard1.wav')
#
# Cell In[4], line 4, in predict_emotion(audio_path)
#       3 def predict_emotion(audio_path):
# ----> 4     audio, sr = librosa.load(audio_path, duration=3, offset=0.5)
#       5     mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=40)
#       6     features = np.mean(mfcc.T, axis=0).reshape(1, -1)
#
# NameError: name 'librosa' is not defined
